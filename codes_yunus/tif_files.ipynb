# %%
# file_name = f"/Users/demir/Documents/Hva_AI/afstudeerproject/Images Carolina/20240312_CKR_Exp35_STHdhQ97HA_96h_+BafA_CCT1_635P_HA_580_A11_460L_1.lif"
file_name = f"/Users/demir/Documents/Hva_AI/afstudeerproject/codes_yunus/8hr_BTZ_image1.tif" # van internet

import numpy as np
import matplotlib.pyplot as plt
import tifffile as tiff

# %%
# Access a specific image directly
img_0 = new.get_image(0)
# Create a list of images using a generator
img_list = [i for i in new.get_iter_image()]
print(img_list)

# %%
image = tiff.imread(file_name)

# image: (2, 2048, 2048) gibi bir şekle sahipse, ilk kanalı gri olarak al
if len(image.shape) == 3 and image.shape[0] in [2, 3, 4]:
    image_gray = image[0]  # Çekirdek bilgisi vs.
    # Eğer en az 3 kanal varsa RGB oluştur
    if image.shape[0] >= 3:
        image_rgb = np.transpose(image[:3], (1, 2, 0))
    else:
        # RGB oluşturmak için eksik kanalları tekrar et
        image_rgb = np.stack([image[0]] * 3, axis=-1)
else:
    image_gray = image
    image_rgb = np.stack([image] * 3, axis=-1)

# Görüntüleri göster
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_gray, cmap='gray')
plt.title("Gri Tonlamalı Görüntü (Cellpose İçin)")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(image_rgb)
plt.title("RGB Görüntü (Son Görselleştirme İçin)")
plt.axis("off")

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [240..2508].
